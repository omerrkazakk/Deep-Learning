# %%
#!pip install torch torchvision

# %%
import torch
import numpy as np

# %%
# pythorch datatypes - tensor

# %%
torch.tensor(10)
# Out:
# tensor(10)

# %%
torch.tensor([10,20,30])
# Out:
# tensor([10, 20, 30])

# %%
scalar = torch.tensor(20)

# %%
scalar
# Out:
# tensor(20)

# %%
type(scalar)
# Out:
# torch.Tensor

# %%
scalar + 5
# Out:
# tensor(25)

# %%
scalar - 5
# Out:
# tensor(15)

# %%
scalar * 2
# Out:
# tensor(40)

# %%
scalar / 2
# Out:
# tensor(10.)

# %%
# kaç boyutlu olduğunu gösterir

# %%
scalar.dim()
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
scalar.item()
# Out:
# 20

# %%
type(scalar.item())
# Out:
# int

# %%
numpy_int = np.int32(20)

# %%
numpy_int
# Out:
# np.int32(20)

# %%
numpy_int + 10
# Out:
# np.int32(30)

# %%
scalar_from_numpy = torch.tensor(numpy_int)

# %%
scalar_from_numpy
# Out:
# tensor(20, dtype=torch.int32)

# %%
new_scalar = torch.tensor(30, dtype=torch.int32)

# %%
new_scalar
# Out:
# tensor(30, dtype=torch.int32)

# %%
tensor_float = torch.tensor(3.14)

# %%
tensor_float
# Out:
# tensor(3.1400)

# %%
tensor_float.dtype
# Out:
# torch.float32

# %%
tensor_float_64 = torch.tensor(3.14 , dtype = torch.float64)

# %%
tensor_float_64
# Out:
# tensor(3.1400, dtype=torch.float64)

# %%
tensor_float_64 * 2
# Out:
# tensor(6.2800, dtype=torch.float64)
